# %%
# %load_ext autoreload
# %autoreload 2

import pandas as pd
from pathlib import Path
import utils

# %%
dataset_name = "amex-default-prediction"
root = f"../datasets/{dataset_name}"
chunksize = 10 ** 6

train_ds_path = Path(f"{root}/train_data.csv")
test_ds_path = Path(f"{root}/test_data.csv")
sample_ds_path = Path(f"{root}/sample_submission.csv")

train_labels = Path(f"{root}/train_labels.csv")
with_target = Path(f"{root}/with_target.csv")

# %%
file = train_ds_path
print(file)
print(utils.get_line(file, 0))
print(utils.get_line(file, 1))

file = test_ds_path
print(file)
print(utils.get_line(file, 0))
print(utils.get_line(file, 1))

file = sample_ds_path
print(file)
print(utils.get_line(file, 0))
print(utils.get_line(file, 1))

file = train_labels
print(file)
print(utils.get_line(file, 0))
print(utils.get_line(file, 1))

file = with_target
print(file)
print(utils.get_line(file, 0))
print(utils.get_line(file, 1))
# Out:
# ../datasets/amex-default-prediction/train_data.csv
# ...
